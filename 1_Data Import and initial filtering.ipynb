# %%
# importing the libraries:

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the cars dataset from a csv file:

df_cars = pd.read_csv('Electric_Vehicle_Population_Data.csv')

# %%
# checking the imported database:

df_cars.head()
# Out:
#    VIN (1-10)    County               City State  Postal Code  Model Year  \
# 0  2C4RC1N71H    Kitsap          Bremerton    WA      98311.0        2017
# 1  2C4RC1N7XL   Stevens           Colville    WA      99114.0        2020
# 2  KNDC3DLCXN    Yakima             Yakima    WA      98908.0        2022
# 3  5YJ3E1EA0J    Kitsap  Bainbridge Island    WA      98110.0        2018
# 4  1N4AZ1CP7J  Thurston           Tumwater    WA      98501.0        2018
#
#        Make     Model                   Electric Vehicle Type  \
# 0  CHRYSLER  PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
# 1  CHRYSLER  PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
# 2       KIA       EV6          Battery Electric Vehicle (BEV)
# 3     TESLA   MODEL 3          Battery Electric Vehicle (BEV)
# 4    NISSAN      LEAF          Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible              33
# 1            Clean Alternative Fuel Vehicle Eligible              32
# 2  Eligibility unknown as battery range has not b...               0
# 3            Clean Alternative Fuel Vehicle Eligible             215
# 4            Clean Alternative Fuel Vehicle Eligible             151
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  23.0       349437882
# 1          0                   7.0       154690532
# 2          0                  14.0       219969144
# 3          0                  23.0       476786887
# 4          0                  35.0       201185253
#
#                   Vehicle Location        Electric Utility  2020 Census Tract
# 0  POINT (-122.6466274 47.6341188)  PUGET SOUND ENERGY INC       5.303509e+10
# 1     POINT (-117.90431 48.547075)             AVISTA CORP       5.306595e+10
# 2  POINT (-120.6027202 46.5965625)              PACIFICORP       5.307700e+10
# 3  POINT (-122.5235781 47.6293323)  PUGET SOUND ENERGY INC       5.303509e+10
# 4     POINT (-122.89692 47.043535)  PUGET SOUND ENERGY INC       5.306701e+10

# %% [markdown]
# # Checking a few dataframe parameters

# %%
# checking the form of the df: it has 159467 entries and 17 columns

df_cars.shape
# Out:
# (159467, 17)

# %%
df_cars.columns # list of columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
# datatypes of column attributes:
df_cars.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                         int64
# Base MSRP                                              int64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# Electric Utility                                      object
# 2020 Census Tract                                    float64
# dtype: object

# %%
# initial df summary statistic results (of course at this stage not all make sense!)

df_cars.describe()
# Out:
#          Postal Code     Model Year  Electric Range     Base MSRP  \
# count  159463.000000  159467.000000   159467.000000  159467.00000
# mean    98170.373635    2020.192510       64.283319    1227.63716
# std      2453.354932       3.010564       94.634277    8930.03468
# min      1730.000000    1997.000000        0.000000       0.00000
# 25%     98052.000000    2018.000000        0.000000       0.00000
# 50%     98122.000000    2021.000000       14.000000       0.00000
# 75%     98370.000000    2023.000000       84.000000       0.00000
# max     99577.000000    2024.000000      337.000000  845000.00000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         159106.000000    1.594670e+05       1.594630e+05
# mean              29.261675    2.140242e+08       5.297287e+10
# std               14.843878    7.959275e+07       1.621526e+09
# min                1.000000    4.385000e+03       1.081042e+09
# 25%               18.000000    1.731016e+08       5.303301e+10
# 50%               33.000000    2.198450e+08       5.303303e+10
# 75%               43.000000    2.448363e+08       5.305307e+10
# max               49.000000    4.792548e+08       5.603300e+10

# %% [markdown]
# # Filtering for columns and rows

# %%
# filtering for e.g. four columns. Also, in custom order, just like in SQL!

df_cars[['VIN (1-10)','City','County', 'State']]
# Out:
#         VIN (1-10)               City    County State
# 0       2C4RC1N71H          Bremerton    Kitsap    WA
# 1       2C4RC1N7XL           Colville   Stevens    WA
# 2       KNDC3DLCXN             Yakima    Yakima    WA
# 3       5YJ3E1EA0J  Bainbridge Island    Kitsap    WA
# 4       1N4AZ1CP7J           Tumwater  Thurston    WA
# ...            ...                ...       ...   ...
# 159462  KM8JBDA2XP          Underwood  Skamania    WA
# 159463  1G1FZ6S02M                Bow    Skagit    WA
# 159464  YV4H60CX2P          Sammamish      King    WA
# 159465  5YJ3E1EA7K         Bellingham   Whatcom    WA
# 159466  7SAYGDEF6N      Camano Island    Island    WA
#
# [159467 rows x 4 columns]

# %%
# filtering for the 5th row (n-1):

df_cars.iloc[4]
# Out:
# VIN (1-10)                                                                        1N4AZ1CP7J
# County                                                                              Thurston
# City                                                                                Tumwater
# State                                                                                     WA
# Postal Code                                                                          98501.0
# Model Year                                                                              2018
# Make                                                                                  NISSAN
# Model                                                                                   LEAF
# Electric Vehicle Type                                         Battery Electric Vehicle (BEV)
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    Clean Alternative Fuel Vehicle Eligible
# Electric Range                                                                           151
# Base MSRP                                                                                  0
# Legislative District                                                                    35.0
# DOL Vehicle ID                                                                     201185253
# Vehicle Location                                                POINT (-122.89692 47.043535)
# Electric Utility                                                      PUGET SOUND ENERGY INC
# 2020 Census Tract                                                              53067011720.0
# Name: 4, dtype: object

# %%
# when searching for County for example:
# at first we should set it as indexing column:

df_cars.set_index('County', inplace = True)

# %%
# now we can filter for it (showing only the first 5)

df_cars.loc['Stevens'].head(5)
# Out:
#          VIN (1-10)             City State  Postal Code  Model Year      Make  \
# County
# Stevens  2C4RC1N7XL         Colville    WA      99114.0        2020  CHRYSLER
# Stevens  5YJ3E1EB7M         Colville    WA      99114.0        2021     TESLA
# Stevens  JN1AZ0CP1B         Colville    WA      99114.0        2011    NISSAN
# Stevens  WBY8P6C51K        Loon Lake    WA      99148.0        2019       BMW
# Stevens  5YJYGAEE8M  Nine Mile Falls    WA      99026.0        2021     TESLA
#
#             Model                   Electric Vehicle Type  \
# County
# Stevens  PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
# Stevens   MODEL 3          Battery Electric Vehicle (BEV)
# Stevens      LEAF          Battery Electric Vehicle (BEV)
# Stevens        I3          Battery Electric Vehicle (BEV)
# Stevens   MODEL Y          Battery Electric Vehicle (BEV)
#
#          Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# County
# Stevens            Clean Alternative Fuel Vehicle Eligible              32
# Stevens  Eligibility unknown as battery range has not b...               0
# Stevens            Clean Alternative Fuel Vehicle Eligible              73
# Stevens            Clean Alternative Fuel Vehicle Eligible             153
# Stevens  Eligibility unknown as battery range has not b...               0
#
#          Base MSRP  Legislative District  DOL Vehicle ID  \
# County
# Stevens          0                   7.0       154690532
# Stevens          0                   7.0       139638901
# Stevens          0                   7.0       224165630
# Stevens          0                   7.0       478044206
# Stevens          0                   7.0       156563697
#
#                         Vehicle Location                   Electric Utility  \
# County
# Stevens     POINT (-117.90431 48.547075)                        AVISTA CORP
# Stevens     POINT (-117.90431 48.547075)                        AVISTA CORP
# Stevens     POINT (-117.90431 48.547075)                        AVISTA CORP
# Stevens      POINT (-117.63454 48.05954)  NO KNOWN ELECTRIC UTILITY SERVICE
# Stevens  POINT (-117.5967686 47.8204962)  NO KNOWN ELECTRIC UTILITY SERVICE
#
#          2020 Census Tract
# County
# Stevens       5.306595e+10
# Stevens       5.306595e+10
# Stevens       5.306595e+10
# Stevens       5.306595e+10
# Stevens       5.306595e+10

# %% [markdown]
# # Sorting Data

# %%
# sort the df based on Cities, descending, only the first 10 imputs:

df_cars.sort_values (by = 'City', ascending = False).head(10)
# Out:
#         VIN (1-10)    City State  Postal Code  Model Year        Make  \
# County
# Yakima  5YJSA1DP4D  Zillah    WA      98953.0        2013       TESLA
# Yakima  1V2DNPE80P  Zillah    WA      98953.0        2023  VOLKSWAGEN
# Yakima  5YJ3E1EBXK  Zillah    WA      98953.0        2019       TESLA
# Yakima  3FMTK3SUXM  Zillah    WA      98953.0        2021        FORD
# Yakima  5YJXCDE26L  Zillah    WA      98953.0        2020       TESLA
# Yakima  7SAYGDEF2P  Zillah    WA      98953.0        2023       TESLA
# Yakima  5YJ3E1EA5P  Zillah    WA      98953.0        2023       TESLA
# Yakima  5UXTA6C03M  Zillah    WA      98953.0        2021         BMW
# Yakima  5UXKT0C59G  Zillah    WA      98953.0        2016         BMW
# Yakima  5YJXCDE23J  Zillah    WA      98932.0        2018       TESLA
#
#                  Model                   Electric Vehicle Type  \
# County
# Yakima         MODEL S          Battery Electric Vehicle (BEV)
# Yakima            ID.4          Battery Electric Vehicle (BEV)
# Yakima         MODEL 3          Battery Electric Vehicle (BEV)
# Yakima  MUSTANG MACH-E          Battery Electric Vehicle (BEV)
# Yakima         MODEL X          Battery Electric Vehicle (BEV)
# Yakima         MODEL Y          Battery Electric Vehicle (BEV)
# Yakima         MODEL 3          Battery Electric Vehicle (BEV)
# Yakima              X5  Plug-in Hybrid Electric Vehicle (PHEV)
# Yakima              X5  Plug-in Hybrid Electric Vehicle (PHEV)
# Yakima         MODEL X          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# County
# Yakima            Clean Alternative Fuel Vehicle Eligible             208
# Yakima  Eligibility unknown as battery range has not b...               0
# Yakima            Clean Alternative Fuel Vehicle Eligible             220
# Yakima  Eligibility unknown as battery range has not b...               0
# Yakima            Clean Alternative Fuel Vehicle Eligible             289
# Yakima  Eligibility unknown as battery range has not b...               0
# Yakima  Eligibility unknown as battery range has not b...               0
# Yakima            Clean Alternative Fuel Vehicle Eligible              30
# Yakima              Not eligible due to low battery range              14
# Yakima            Clean Alternative Fuel Vehicle Eligible             238
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# County
# Yakima      69900                  15.0       161861780
# Yakima          0                  15.0       256438024
# Yakima          0                  15.0         9404685
# Yakima          0                  15.0       195227735
# Yakima          0                  15.0       104180338
# Yakima          0                  15.0       253710397
# Yakima          0                  15.0       244636619
# Yakima          0                  15.0       154479965
# Yakima          0                  15.0       206822717
# Yakima          0                  15.0       170230959
#
#                    Vehicle Location Electric Utility  2020 Census Tract
# County
# Yakima  POINT (-120.26317 46.40556)       PACIFICORP       5.307700e+10
# Yakima  POINT (-120.26317 46.40556)       PACIFICORP       5.307700e+10
# Yakima  POINT (-120.26317 46.40556)       PACIFICORP       5.307700e+10
# Yakima  POINT (-120.26317 46.40556)       PACIFICORP       5.307700e+10
# Yakima  POINT (-120.26317 46.40556)       PACIFICORP       5.307700e+10
# Yakima  POINT (-120.26317 46.40556)       PACIFICORP       5.307700e+10
# Yakima  POINT (-120.26317 46.40556)       PACIFICORP       5.307700e+10
# Yakima  POINT (-120.26317 46.40556)       PACIFICORP       5.307700e+10
# Yakima  POINT (-120.26317 46.40556)       PACIFICORP       5.307700e+10
# Yakima  POINT (-120.1934 46.345135)       PACIFICORP       5.307700e+10
